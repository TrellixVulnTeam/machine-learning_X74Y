# %% [markdown]
# # `d2l` 패키지 색인
#
# |함수 또는 클래스 이름|Relevant Chapter|
# |:--|:-:|
# | `bbox_to_rect`|[Object Detection and Bounding Boxes](../chapter_computer-vision/bounding-box.ipynb)|
# | `Benchmark`|[Asynchronous Computation](../chapter_computational-performance/async-computation.ipynb)|
# | `corr2d`|[Two-dimensional Convolutional Layer](../chapter_convolutional-neural-networks/conv-layer.ipynb)|
# | `count_tokens`|[Sentiment Classification: Using Recurrent Neural Networks](../chapter_natural-language-processing/sentiment-analysis-rnn.ipynb)|
# | `data_iter`|[Linear Regression Implementation from Scratch](../chapter_deep-learning-basics/linear-regression-scratch.ipynb)|
# | `data_iter_consecutive`|[Language Model Data Set (Jay Chou album lyrics)](../chapter_recurrent-neural-networks/lang-model-dataset.ipynb)|
# | `data_iter_random`|[Language Model Data Set (Jay Chou album lyrics)](../chapter_recurrent-neural-networks/lang-model-dataset.ipynb)|
# | `download_imdb`|[Sentiment Classification: Using Recurrent Neural Networks](../chapter_natural-language-processing/sentiment-analysis-rnn.ipynb)|
# | `download_voc_pascal`|[Semantic Segmentation and Data Sets](../chapter_computer-vision/semantic-segmentation-and-dataset.ipynb)|
# | `evaluate_accuracy`|[Image Augmentation](../chapter_computer-vision/image-augmentation.ipynb)|
# | `get_data_ch7`|[Mini-batch Stochastic Gradient Descent](../chapter_optimization/minibatch-sgd.ipynb)|
# |`get_fashion_mnist_labels`|[Image Classification Data Set(Fashion-MNIST)](../chapter_deep-learning-basics/fashion-mnist.ipynb)|
# | `get_tokenized_imdb`|[Sentiment Classification: Using Recurrent Neural Networks](../chapter_natural-language-processing/sentiment-analysis-rnn.ipynb)|
# | `get_vocab_imdb`|[Sentiment Classification: Using Recurrent Neural Networks](../chapter_natural-language-processing/sentiment-analysis-rnn.ipynb)|
# | `grad_clipping`|[Recurrent Neural Network Implementation from Scratch](../chapter_recurrent-neural-networks/rnn-scratch.ipynb)|
# | `linreg`|[Linear Regression Implementation from Scratch](../chapter_deep-learning-basics/linear-regression-scratch.ipynb)|
# | `load_data_fashion_mnist`|[Deep Convolutional Neural Networks (AlexNet)](../chapter_convolutional-neural-networks/alexnet.ipynb)|
# |`load_data_jay_lyrics`|[Language Model Data Set (Jay Chou album lyrics)](../chapter_recurrent-neural-networks/lang-model-dataset.ipynb)|
# |`load_data_pikachu`|[Object Detection Data Set(Pikachu)](../chapter_computer-vision/object-detection-dataset.ipynb)|
# | `plt`|[Linear Regression Implementation from Scratch](../chapter_deep-learning-basics/linear-regression-scratch.ipynb)|
# | `predict_rnn`|[Recurrent Neural Network Implementation from Scratch](../chapter_recurrent-neural-networks/rnn-scratch.ipynb)|
# | `predict_rnn_gluon`|[Concise Implementation of Recurrent Neural Networks](../chapter_recurrent-neural-networks/rnn-gluon.ipynb)|
# | `predict_sentiment`|[Sentiment Classification: Using Recurrent Neural Networks](../chapter_natural-language-processing/sentiment-analysis-rnn.ipynb)|
# | `preprocess_imdb`|[Sentiment Classification: Using Recurrent Neural Networks](../chapter_natural-language-processing/sentiment-analysis-rnn.ipynb)|
# | `read_imdb`|[Sentiment Classification: Using Recurrent Neural Networks](../chapter_natural-language-processing/sentiment-analysis-rnn.ipynb)|
# | `read_voc_images`|[Semantic Segmentation and Data Sets](../chapter_computer-vision/semantic-segmentation-and-dataset.ipynb)|
# | `Residual`|[Residual Networks (ResNet)](../chapter_convolutional-neural-networks/resnet.ipynb)|
# | `resnet18`|[Concise Implementation of Multi-GPU Computing](../chapter_computational-performance/multiple-gpus-gluon.ipynb)|
# | `RNNModel`|[Concise Implementation of Recurrent Neural Networks](../chapter_recurrent-neural-networks/rnn-gluon.ipynb)|
# |`semilogy` |[Model Selection](../chapter_deep-learning-basics/underfit-overfit.ipynb)|
# | `set_figsize`|[Linear Regression Implementation from Scratch](../chapter_deep-learning-basics/linear-regression-scratch.ipynb)|
# | `sgd`|[Linear Regression Implementation from Scratch](../chapter_deep-learning-basics/linear-regression-scratch.ipynb)|
# | `show_bboxes`|[Anchor Boxes](../chapter_computer-vision/anchor.ipynb)|
# |`show_fashion_mnist`|[Image Classification Data Set(Fashion-MNIST)](../chapter_deep-learning-basics/fashion-mnist.ipynb)|
# | `show_images`|[Image Augmentation](../chapter_computer-vision/image-augmentation.ipynb)|
# | `show_trace_2d`|[Gradient Descent and Stochastic Gradient Descent](../chapter_optimization/gd-sgd.ipynb)|
# | `squared_loss`|[Linear Regression Implementation from Scratch](../chapter_deep-learning-basics/linear-regression-scratch.ipynb)|
# | `to_onehot`|[Recurrent Neural Network Implementation from Scratch](../chapter_recurrent-neural-networks/rnn-scratch.ipynb)|
# | `train`|[Image Augmentation](../chapter_computer-vision/image-augmentation.ipynb)|
# | `train_2d`|[Gradient Descent and Stochastic Gradient Descent](../chapter_optimization/gd-sgd.ipynb)|
# | `train_and_predict_rnn`|[Recurrent Neural Network Implementation from Scratch](../chapter_recurrent-neural-networks/rnn-scratch.ipynb)|
# | `train_and_predict_rnn_gluon `|[Concise Implementation of Recurrent Neural Networks](../chapter_recurrent-neural-networks/rnn-gluon.ipynb)|
# | `train_ch3`|[Softmax Regression Implementation from Scratch](../chapter_deep-learning-basics/softmax-regression-scratch.ipynb)|
# | `train_ch5`|[Convolutional Neural Networks (LeNet)](../chapter_convolutional-neural-networks/lenet.ipynb)|
# | `train_ch7`|[Mini-batch Stochastic Gradient Descent](../chapter_optimization/minibatch-sgd.ipynb)|
# | `train_gluon_ch7`|[Mini-batch Stochastic Gradient Descent](../chapter_optimization/minibatch-sgd.ipynb)|
# | `try_all_gpus`|[Image Augmentation](../chapter_computer-vision/image-augmentation.ipynb)|
# | `try_gpu`|[Convolutional Neural Networks (LeNet)](../chapter_convolutional-neural-networks/lenet.ipynb)|
# | `use_svg_display`|[Linear Regression Implementation from Scratch](../chapter_deep-learning-basics/linear-regression-scratch.ipynb)|
# | `VOC_CLASSES`|[Semantic Segmentation and Data Sets](../chapter_computer-vision/semantic-segmentation-and-dataset.ipynb)|
# | `VOC_COLORMAP`|[Semantic Segmentation and Data Sets](../chapter_computer-vision/semantic-segmentation-and-dataset.ipynb)|
# | `voc_label_indices`|[Semantic Segmentation and Data Sets](../chapter_computer-vision/semantic-segmentation-and-dataset.ipynb)|
# | `voc_rand_crop`|[Semantic Segmentation and Data Sets](../chapter_computer-vision/semantic-segmentation-and-dataset.ipynb)|
# | `VOCSegDataset`|[Semantic Segmentation and Data Sets](../chapter_computer-vision/semantic-segmentation-and-dataset.ipynb)|
